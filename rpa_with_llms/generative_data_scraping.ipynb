# %% [markdown]
# ## Robotic Process Automation with Generative AI
#
# <b>By:</b> <a href='https://www.evolveailabs.com/'>Evolve AI Labs</a><br>
#
# This notebook aims to illustrate how to use Generative AI models; specifically <a href='https://en.wikipedia.org/wiki/Large_language_model'>LLMs</a> for <a href='https://en.wikipedia.org/wiki/Robotic_process_automation'>Robotic Process Automation</a>. <br> <br>
# Robotic Process Automation is a form of automating business processes using software programs. These programs can include simple logical constructs with graphs or can include complicated Artificial Intelligence models. One of the  strengths of LLMs is translation and this can be leveraged for certain RPA tasks like Web Scraping as shown in the code below. <br> <br>
#
# ### Advantages
# Generative AI can augment the benefits of RPA by further
# - <b>improving productivity:</b> build RPA workflows faster
# - <b>reducing complexity:</b> reduce dependence on SMEs
# - <b>reducing costs:</b> simplify workflows which reduce overheads
#
# This notebook shows how to scrape a website using Generative AI.

# %% [markdown]
# ## Libraries
# - <a href='https://www.selenium.dev/'>Selenium</a>: The most important part of any web scraping exercise is to extract page content. Scraping JavaScript rendered pages is not as easy as Static webpages because they are rendered differently. Selenium is a popular browser automation tool that can help us scrape JS rendered pages.
# - <a href='https://www.langchain.com/'>Langchain</a>: Once the page source is available, we will use Langchain API to send the HTML to an LLM. Langchain is a popular and easy to use python tool for building LLM applications.

# %%
import chromedriver_autoinstaller
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import Chrome 
from selenium.webdriver.common.by import By 
from selenium import webdriver
import os
import requests
import time
from langchain.chat_models import ChatOpenAI

# %% [markdown]
# ## LLM
# We will be using the <a href='https://platform.openai.com/docs/models/gpt-3-5'>GPT 3.5</a> Turbo LLM provided by <a href='https://openai.com/'>OpenAI</a> to translate the page source in HTML to the outcome we require. You'll need an openai API key to run this notebook.

# %%
OPENAI_KEY = <<OPENAI KEY>>
MODEL_NAME = "gpt-3.5-turbo-16k"

# %% [markdown]
# ## Scraper
# In the below function, we show how to extract the page source of a JavaScript rendered website and then send the HTML to the GPT 3.5 LLM and request it to extract information into a list for downstream consumption. Selenium is used to render the page and get the HTML of the page. And the Langchain API is used to send the page source to the LLM and return the output.

# %%
def gpt_scraper(url, instructions):
    ts = 10
    chromedriver_autoinstaller.install()
    options = webdriver.ChromeOptions() 
    options.add_argument("--headless")
    options.page_load_strategy = "none"
    driver = Chrome(options=options) 
    driver.implicitly_wait(ts)
    driver.get(url) 
    time.sleep(ts)
    
    prompt = "You are an agent helping scrape data \
    from an HTML page. Using the following HTML, "
    prompt = prompt + instructions + " : " + driver.page_source
    chat = ChatOpenAI(temperature=0, 
                      model=MODEL_NAME, 
                      openai_api_key=OPENAI_KEY)
    response = chat.predict(prompt)
    return response

# %% [markdown]
# ## Demo
# The Raspberry PI website lists a bunch of technical documents that we want to scrape. Instead of writing all the code to extract the HTML of the page and identify lists and find the href links, we can just pass the url and instructions to the above function and get results.

# %%
# %%time
url = "https://datasheets.raspberrypi.com/?_gl=1*1itvbwk*_ga*MTA0NjY5MTcyOS4xNzAxNjczMTkz*_ga_22FD70LWDS*MTcwMTY3MzE5My4xLjAuMTcwMTY3MzE5My4wLjAuMA.."
instructions = "provide the links to all documents in the page as a list."
response = gpt_scraper(url, instructions)
# Out:
# CPU times: user 486 ms, sys: 154 ms, total: 640 ms
# Wall time: 2min 2s

# %%
print(response)
# Out:
# - audio/codec-zero-phat-product-brief.pdf
# - audio/dac-plus-hat-product-brief.pdf
# - audio/dac-pro-hat-product-brief.pdf
# - audio/digiamp-plus-hat-product-brief.pdf
# - bcm2711/bcm2711-peripherals.pdf
# - bcm2835/bcm2835-peripherals.pdf
# - bcm2836/bcm2836-peripherals.pdf
# - build-hat/build-hat-python-library.pdf
# - build-hat/build-hat-serial-protocol.pdf
# - build-hat/getting-started-build-hat.pdf
# - build-hat/raspberry-pi-build-hat-power-supply-product-brief.pdf
# - build-hat/raspberry-pi-build-hat-product-brief.pdf
# - camera/camera-extended-spectral-sensitivity.pdf
# - camera/camera-module-2-mechanical-drawing.pdf
# - camera/camera-module-2-schematics.pdf
# - camera/camera-module-3-product-brief.pdf
# - camera/camera-module-3-schematics.pdf
# - camera/camera-module-3-standard-mechanical-drawing.pdf
# - camera/camera-module-3-wide-mechanical-drawing.pdf
# - camera/picamera2-manual.pdf
# - camera/raspberry-pi-camera-guide.pdf
# - camera/raspberry-pi-image-signal-processor-specification.pdf
# - case-fan/case-fan-product-brief.pdf
# - case/case-for-raspberry-pi-5-product-brief.pdf
# - case/raspberry-pi-3-a-plus-case-mechanical-drawing.pdf
# - case/raspberry-pi-3-b-plus-case-mechanical-drawing.pdf
# - case/raspberry-pi-zero-case-mechanical-drawing.pdf
# - case/raspberry-pi-zero-case-with-camera-mechanical-drawing.pdf
# - case/raspberry-pi-zero-case-with-gpio-mechanical-drawing.pdf
# - cm/cm1-and-cm3-datasheet.pdf
# - cm/cm1-schematics.pdf
# - cm/cm3-plus-datasheet.pdf
# - cm/cm3-schematics.pdf
# - cm/example1-overlay.dts
# - cm/minimal-cm-dt-blob.dts
# - cm4/CM4-step.zip
# - cm4/CM4Lite-step.zip
# - cm4/cm4-antenna-kit-product-brief.pdf
# - cm4/cm4-datasheet.pdf
# - cm4/cm4-product-brief.pdf
# - cm4io/CM4IO-KiCAD.zip
# - cm4io/CM4IOUSB3-KiCAD.zip
# - cm4io/cm4io-datasheet.pdf
# - cm4io/cm4io-product-brief.pdf
# - cm4io/cm4iousb3-appnote.pdf
# - cm4s/cm4s-datasheet.pdf
# - cm4s/cm4s-product-brief.pdf
# - cmcda/RPi-CMCDA-1P1.zip
# - cmcda/cmcda-schematics.pdf
# - cmio/RPi-CMIO-R1P2.zip
# - cmio/RPi-CMIO-R3P0.zip
# - cmio/cmio-schematics.pdf
# - cmio/dt-blob-cam1.bin
# - cmio/dt-blob-cam1.dts
# - cmio/dt-blob-disp0-only.bin
# - cmio/dt-blob-disp0-only.dts
# - cmio/dt-blob-disp1-cam1.bin
# - cmio/dt-blob-disp1-cam1.dts
# - cmio/dt-blob-disp1-cam2.bin
# - cmio/dt-blob-disp1-cam2.dts
# - cmio/dt-blob-disp1-only.bin
# - cmio/dt-blob-disp1-only.dts
# - cmio/dt-blob-dualcam.bin
# - cmio/dt-blob-dualcam.dts
# - cooling/raspberry-pi-active-cooler-mechanical-drawing.pdf
# - cooling/raspberry-pi-active-cooler-product-brief.pdf
# - debug/debug-connector-specification.pdf
# - debug/debug-swd-cable-specification.pdf
# - debug/debug-uart-cable-specification.pdf
# - debug/raspberry-pi-debug-probe-mechanical-drawing.pdf
# - debug/raspberry-pi-debug-probe-product-brief.pdf
# - debug/raspberry-pi-debug-probe-schematics.pdf
# - display/7-inch-display-mechanical-drawing.pdf
# - display/7-inch-display-product-brief.pdf
# - gs-camera/gs-camera-mechanical-drawing.pdf
# - gs-camera/gs-camera-product-brief.pdf
# - hat/hat-plus-specification.pdf
# - hq-camera/c-mount-lens-guide.pdf
# - hq-camera/cs-mount-lens-guide.pdf
# - hq-camera/hq-camera-cs-lensmount-drawing.pdf
# - hq-camera/hq-camera-cs-mechanical-drawing.pdf
# - hq-camera/hq-camera-m12-mechanical-drawing.pdf
# - hq-camera/hq-camera-product-brief.pdf
# - hq-camera/hq-camera-schematics.pdf
# - keyboard-mouse/DE-layout.png
# - keyboard-mouse/DK-layout.png
# - keyboard-mouse/ES-layout.png
# - keyboard-mouse/FR-layout.png
# - keyboard-mouse/IT-layout.png
# - keyboard-mouse/NO-layout.png
# - keyboard-mouse/PT-layout.png
# - keyboard-mouse/SE-layout.png
# - keyboard-mouse/UK-layout.png
# - keyboard-mouse/US-layout.png
# - keyboard-mouse/getting-started-with-keyboard-and-mouse.pdf
# - keyboard-mouse/keyboard-mouse-mechanical-drawing.pdf
# - keyboard-mouse/keyboard-mouse-product-brief.pdf
# - pcie/pcie-connector-standard.pdf
# - pico/Pico-R3-A4-Pinout.pdf
# - pico/Pico-R3-Fritzing.fzpz
# - pico/Pico-R3-step.zip
# - pico/PicoH-Fritzing.fzpz
# - pico/RPi-Pico-R3-PUBLIC-20200119.zip
# - pico/getting-started-with-pico-JP.pdf
# - pico/getting-started-with-pico.pdf
# - pico/pico-datasheet.pdf
# - pico/pico-product-brief.pdf
# - pico/raspberry-pi-pico-c-sdk.pdf
# - pico/raspberry-pi-pico-python-sdk.pdf
# - picow/PicoW-A4-Pinout.pdf
# - picow/PicoW-Fritzing.fzpz
# - picow/PicoW-HighRes.jpg
# - picow/PicoW-step.zip
# - picow/RPi-PicoW-PUBLIC-20220607.zip
# - picow/connecting-to-the-internet-with-pico-w.pdf
# - picow/pico-w-datasheet.pdf
# - picow/pico-w-product-brief.pdf
# - poe/poe-hat-mechanical-drawing.pdf
# - poe/poe-hat-product-brief.pdf
# - poe/poe-plus-hat-product-brief.pdf
# - power-supply/15w-usb-c-power-supply-product-brief.pdf
# - power-supply/27w-usb-c-power-supply-product-brief.pdf
# - power-supply/micro-usb-power-supply-product-brief.pdf
# - product/product-catalogue-2023.pdf
# - rp1/rp1-peripherals.pdf
# - rp2040/Minimal-KiCAD.zip
# - rp2040/VGA-KiCAD.zip
# - rp2040/VGA-PicoW-KiCAD.zip
# - rp2040/hardware-design-with-rp2040-JP.pdf
# - rp2040/hardware-design-with-rp2040.pdf
# - rp2040/rp2040-datasheet.pdf
# - rp2040/rp2040-product-brief.pdf
# - rp2040/vga-for-pico-w-schematics.pdf
# - rpi/raspberry-pi-a-plus-reduced-schematics.pdf
# - rpi/raspberry-pi-b-plus-mecahnical-drawing.dxf
# - rpi/raspberry-pi-b-plus-mecahnical-drawing.pdf
# - rpi/raspberry-pi-b-plus-reduced-schematics.pdf
# - rpi2/raspberry-pi-2-b-reduced-schematics.pdf
# - rpi3/raspberry-pi-3-a-mechanical-drawing.pdf
# - rpi3/raspberry-pi-3-a-plus-mechanical-drawing.pdf
# - rpi3/raspberry-pi-3-a-plus-product-brief.pdf
# - rpi3/raspberry-pi-3-a-plus-reduced-schematics.pdf
# - rpi3/raspberry-pi-3-a-schematics.pdf
# - rpi3/raspberry-pi-3-b-mechanical-drawing.dxf
# - rpi3/raspberry-pi-3-b-mechanical-drawing.pdf
# - rpi3/raspberry-pi-3-b-plus-mechanical-drawing.dxf
# - rpi3/raspberry-pi-3-b-plus-mechanical-drawing.pdf
# - rpi3/raspberry-pi-3-b-plus-product-brief.pdf
# - rpi3/raspberry-pi-3-b-plus-reduced-schematics.pdf
# - rpi3/raspberry-pi-3-b-reduced-schematics.pdf
# - rpi4/raspberry-pi-4-datasheet.pdf
# - rpi4/raspberry-pi-4-mechanical-drawing.dxf
# - rpi4/raspberry-pi-4-mechanical-drawing.pdf
# - rpi4/raspberry-pi-4-product-brief.pdf
# - rpi4/raspberry-pi-4-reduced-schematics.pdf
# - rpi400/DE-layout.png
# - rpi400/DK-layout.png
# - rpi400/ES-layout.png
# - rpi400/FR-layout.png
# - rpi400/IT-layout.png
# - rpi400/JP-layout.png
# - rpi400/NO-layout.png
# - rpi400/PT-layout.png
# - rpi400/SE-layout.png
# - rpi400/UK-layout.png
# - rpi400/US-layout.png
# - rpi400/raspberry-pi-400-product-brief.pdf
# - rpi5/RaspberryPi5-step.zip
# - rpi5/raspberry-pi-5-mechanical-drawing.pdf
# - rpi5/raspberry-pi-5-product-brief.pdf
# - rpizero/raspberry-pi-zero-mechanical-drawing.pdf
# - rpizero/raspberry-pi-zero-reduced-schematics.pdf
# - rpizero/raspberry-pi-zero-w-mechanical-drawing.pdf
# - rpizero/raspberry-pi-zero-w-reduced-schematics.pdf
# - rpizero2/raspberry-pi-zero-2-w-mechanical-drawing.pdf
# - rpizero2/raspberry-pi-zero-2-w-product-brief.pdf
# - rpizero2/raspberry-pi-zero-2-w-reduced-schematics.pdf
# - rpizero2/raspberry-pi-zero-2-w-test-pads.pdf
# - sense-hat/sense-hat-mechanical-drawing.pdf
# - sense-hat/sense-hat-product-brief.pdf
# - sense-hat/sense-hat-schematics.pdf
# - soft/blink.uf2
# - soft/blink_picow.uf2
# - soft/flash_nuke.uf2
# - soft/hello_world.uf2
# - soft/micropython-firmware-pico-w-130623.uf2
# - soft/micropython-firmware-pico-w-290622.uf2
# - soft/prepare_pxetools.sh
# - soft/pxetools.py
# - tv-hat/getting-started-with-tv-hat.pdf
# - tv-hat/tv-hat-mechanical-drawing.pdf
# - tv-hat/tv-hat-product-brief.pdf
# - usb/USB-tester-KiCAD.zip

# %% [markdown]
# ## Conclusion
# Using Generative AI, we were augment RPA staples like Web Scraping with minimal knowledge of DOM in JavaScript. This is how Generative AI and LLMs can help augment the benefits of Robotic Process Automation.
